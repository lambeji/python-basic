# %% [markdown]
# 1. What is the difference between a function and a method in Python?
# - A function is a block of code that performs a task and is not tied to any object.
# - # Function example
# def greet(name):
#     return f"Hello, {name}!"
#
# print(greet("Chinmay"))
# - A method is associated with an object and can access/modify the object’s state.
# # Method example
# class Person:
#     def __init__(self, name):
#         self.name = name
#
#     def greet(self):  # 'self' refers to the instance
#         return f"Hello, {self.name}!"
#
# p = Person("Chinmay")
# print(p.greet())  # Output: Hello, Chinmay!

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
# -Arguments - The actual values passed to the function when it is called (real data).
# - Paramenters- The variables listed in a function definition (placeholders).
# - # Here, 'name' is a **parameter**
# def greet(name):
#     print(f"Hello, {name}!")
#
# # Here, "Chinmay" is an **argument**
# greet("Chinmay")

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
# - def greet(name):       # Function definition
#     print(f"Hello, {name}!")
#
# greet("Chinmay")
# -def greet(name="Guest"):
#     print(f"Hello, {name}!")
#
# greet()                # Uses default → Output: Hello, Guest
# greet("Chinmay")       # Overrides default → Output: Hello, Chinmay

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
# - The return statement is used to send a value back from a function to the place where it was called. It ends the function execution and optionally passes back a result.
# -def add(a, b):
#     return a + b
#
# result = add(3, 5)
# print(result)

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
# - An iterable is any Python object that can return an iterator when passed to the built-in iter() function.
# Lists ([1, 2, 3])
#
# Tuples ((1, 2, 3))
#
# Strings ("hello")
#
# - An iterator is an object that represents a stream of data. It keeps internal state and produces the next value when you call next() on it.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined
# - A generator in Python is a special type of iterator that lets you iterate through a sequence of values, but generates each value only when needed
# def count_up_to(n):
#     count = 1
#     while count <= n:
#         yield count
#         count += 1

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# Generators don’t store all values in memory.
#
# They yield one item at a time — perfect for large datasets.
# def generate_numbers():
#     for i in range(1, 1000000):
#         yield i
#         #This will use very little memory, even though it can generate a million numbers.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
# - A lambda function is an anonymous (nameless), one-line function in Python used to perform simple operations quickly.
# square = lambda x: x ** 2
# print(square(5))

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
# - The map() function is used to apply a function to every item in an iterable (like a list, tuple, etc.) and return a new iterator with the results.
# nums = [1, 2, 3, 4]
#
# # Using map with a lambda function
# squares = map(lambda x: x ** 2, nums)
#
# print(list(squares))

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# #Map() Applies a function to every item in an iterable and returns an iterator of the transformed items.
# -nums = [1, 2, 3]
# result = map(lambda x: x * 2, nums)
# print(list(result))
# #reduce() Applies a function cumulatively to the items, so as to reduce the iterable to a single value.
# -nums = [1, 2, 3, 4]
# result = reduce(lambda x, y: x + y, nums)
# print(result)
# #filter() Applies a function to each item, and only keeps the items where the function returns True.
# -nums = [1, 2, 3, 4]
# result = filter(lambda x: x % 2 == 0, nums)
# print(list(result))

# %% [markdown]
#  11 Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![WhatsApp Image 2025-06-27 at 12.40.31_1b48ebee.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_of_evens(numbers):
    total = 0
    for i in numbers:
        if type(i) == int and i % 2 == 0:
            total += i
    return total

# %%
print(sum_of_evens([1, 2, 3, 4, 5, 6]))
# Out:
# 12

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
 def reverse_string(s):
    return s[::-1]

# %%
    print(reverse_string("chinmay_lambe"))
# Out:
# ebmal_yamnihc

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_nu(n):
  result=[]
  for i in range (n):
    result.append(i**2)
  return result
square_nu(11)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms

# %% [markdown]
# Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for i in range(max_exponent + 1):
        yield 2 ** i

# %%
result = list(powers_of_two(5))
print(result)
# Out:
# [1, 2, 4, 8, 16, 32]

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

# %%
with open("example.txt", "w") as f:
    f.write("Hello world\n")
    f.write("This is a file\n")
    f.write("With multiple lines\n")


def read_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()


print("Reading lines from the file:")
for line in read_lines("example.txt"):
    print(line)
# Out:
# Reading lines from the file:
# Hello world
# This is a file
# With multiple lines

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
data = [(1, 4), (3, 1), (5, 2), (2, 3)]


sorted_data = sorted(data, key=lambda x: x[1])


print("Sorted list:", sorted_data)
# Out:
# Sorted list: [(3, 1), (5, 2), (2, 3), (1, 4)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

# %%
celsius_temps = [0, 20, 37, 100]


fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))


print("Celsius:    ", celsius_temps)
print("Fahrenheit: ", fahrenheit_temps)
# Out:
# Celsius:     [0, 20, 37, 100]
# Fahrenheit:  [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string

# %%
text = "Hello World, Python is awesome!"


def is_not_vowel(char):
    return char.lower() not in 'aeiou'


result = ''.join(filter(is_not_vowel, text))


print("Original string: ", text)
print("Without vowels:  ", result)
# Out:
# Original string:  Hello World, Python is awesome!
# Without vowels:   Hll Wrld, Pythn s wsm!

# %% [markdown]
# question 11

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]


def process_orders(order_list):
    result = []
    for order in order_list:
        order_num = order[0]
        total = order[2] * order[3]
        if total < 100:
            total += 10
        result.append((order_num, round(total, 2)))
    return result


final_result = process_orders(orders)
print(final_result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]

# %% [markdown]
# Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]


result = list(map(lambda order: (
    order[0],
    round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)
), orders))


print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
